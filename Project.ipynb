# %% [markdown]
# # $$\textbf{Project lab data analysis}$$
#
# ## $\textbf{Question}$:
#
# Given the observed range of masses $[m_{min},m_{max}]$ measured by 3dHST at its highest redshift:
#
# 1) Does the galaxies’ mass function ($\mathrm{GMF}$) in  $[m_{min},m_{max}]$ change as a function of redshift?
# 2) If so, which processes determine its evolution? It doesn't change, so we moved onto more interesting topics.
#
# 3) Found $\mathrm{GMF(z)}$, Can we predict how the mass below M_min is distributed at higher redshift? (apparently non-contemplabile, so ciaone).
#
# $\textbf{Real question:}$
# 4) Given the SFR vs redshift projection of the 3-dimensional dataset (redshift, masses, sfr), are there some relations we can observe? Is there any functional dependency between the SFR and the $z$ that can be related to some model we developed?
#
# # 1) $\textbf{Closed box model}$:
#
# ## $\textbf{Assumptions for this model}$:
#
# - proportionality to the gas mass of the SFR
# - close box assumption (only change in $m_{gas}$ is given by the SFR and not incoming external gas or gas leaving the galaxy $\rightarrow$ $m^{in}_{gas}=0 \ \ \ m^{out}_{gas}=0 $)
# - $\epsilon$ is a constant
#
# ![](Close_box_model.png)
#
# We assume that the law describing the $\mathrm{SFR}$ as a function of time can be written as:
#
# $$\mathrm{SFR} = \epsilon m_{gas}(t)^{\alpha}$$
#
# $$\frac{dm_{gas}(t)}{dt} = \epsilon m_{gas}(t)$$
#
# Solving the equations we get:
#
# $$m_{gas} = m_{gas}(0) \cdot (1 - e^{-\epsilon (t-t_0)})$$
#
# $$\mathrm{SFR} = \epsilon m_{gas, 0} \cdot e^{- \epsilon (t-t_0)}$$
#
# $$\mathrm{sSFR} = \epsilon \frac{e^{-\epsilon(t-t_0)}}{1 - e^{-\epsilon(t-t_0)}}$$
#
#
# ## $\textbf{Discussion (points we stressed)}$:
#
# - the $z$-taken data are strongly biased at higher $z$ values because of their relative distance from us, making it difficult to see smaller and less luminous masses. This means that our analysis can be considered more reliable if we choose only a specific range of masses to do statistics with.
#
# - the area increases at higher redshifts, and this leads to us seeing more rare elements ("big-L" galaxies, for instance) than the patch at smaller redshift (even if we learned that from 0.5 to 2 the differences are negligible, WTF)
#
#
# # 2) $\textbf{Open box model}$:
#
# ## $\textbf{Assumptions for this model}$:
#
# - proportionality to the gas mass of the SFR
# - $\rho_{DM}$ is a constant
# - Virialized mass = DM mass
#
# ![](Open_box_model.png)
#
# We decided to adopt an accretion disk model around the central supermassive black hole of the galaxy. There will be an incoming mass as well as an outcoming mass that will respectively add up to the already present gas, while there will be processes contributing to the outcoming.
#
# Let's restart from the equation above, by adding up two terms of incoming mass, and outcoming mass:
#
# $$\frac{dm_{gas}(t)}{dt} = \epsilon m_{gas}(t) + \dot{m}_{in} - \dot{m}_{out}$$
#
# ### $$\dot{m}_{out}$$
#
# There may be a lot of reasons for the mass to get to the outside. Here we report some of the hypotheses on the processes:
#
# - AGM;
# - accretion rate of the disk around the black hole (where we introduce a dependency on the $m_{bh}$;
# - supernovae ejection;
# - stripping of gas from another galaxy, the run pressure stripping process, which is only relevant at higher masses (e.g. very steep potential well).
#
# We concentrated on the supernovae ejections, basing our analysis on a very specific type of supernova explosion, the $\textit{type 1-A}$ kind. This was because we wanted to write the rate of ejection in terms of the $\texttt{SFR}$ such that:
#
# $$\dot{m}_{out} = \eta \texttt{SFR}$$
#
# The equation above then becomes:
#
# $$\frac{dm_{gas}}{dt} = -(1 + \eta) \texttt{SFR} + \dot{m}_{in}$$
#
# ### $$\dot{m}_{in}$$
#
# Here again we proposed some hypotheses:
#
# - The accretion of dark matter coming into the virialized sphere;
# - Galaxies mergers;
#
# We went for the first option:
#
# From the above figure $dh$ is the thickness of the sphere, so that $dm = \rho dV$, where $\rho = \rho_{DM} = K$. Dividing the contribution from the 2D surface we observe:
#
# $$dV = \Sigma_{vir} dh = 4 \pi R_{vir}^2 dr$$
#
# where $R_{vir}$ is the radius of the virialized part of the system.
#
# $\dot{m}_{vir}$ becomes:
#
#
# $$\dot{m}_{vir} = \rho_{DM} \Sigma_{DM} \frac{dh}{dt} = \rho_{DM} \Sigma_{DM} v_{DM} = \delta\rho_{0} (1+z)^3 = \delta\rho_{0} 4 \pi R_{vir}^2 \sqrt{\frac{G m_{vir}}{R_{vir}}} = ... = (\delta\rho_{0}G)^{1/2} (1+z)^{3/2} m_{vir}$$
#
# The previous equation was:
#
# $$\frac{dm_{gas}}{dt} = -(1 + \eta) \texttt{SFR} + \dot{m}_{in}$$
#
# We here have two options to solve it.
#
# ### Option A
#
# Consider the gas reservoir (our galaxy) at equilibrium. This means that $\frac{dm_{gas}}{dt} = 0$.
#
# From the graphs we see that the $\texttt{sSFR = \frac{\texttt{SFR}}{m_{*}}}$ is constant in mass; our goal is to check if this model can be compatible with this result. In the case of equilibrium we have this relation:
#
# $$\dot{m}_{gas} \propto \dot{m}_{DM} \propto \xi \dot{m}_{vir, in} \propto \xi m_{vir} (1+z)^{3/2}$$
#
# where $\dot{M}_{DM} = $ is the accretion rate of dark matter evaluated above. From the cited article ([here the article](https://watermark.silverchair.com/mnras0398-1858.pdf?token=AQECAHi208BE49Ooan9kkhW_Ercy7Dm3ZL_9Cf3qfKAc485ysgAAAtYwggLSBgkqhkiG9w0BBwagggLDMIICvwIBADCCArgGCSqGSIb3DQEHATAeBglghkgBZQMEAS4wEQQMu9PngnPLnxtBx1pRAgEQgIICiSo0H60UesLzdG1uwy9sTqOEI7CWS9FKYavr8btpkZQI9WWBWusgxz3wa72J6Yx_0xqy2UgPtmJdfRYKx9c6sTIxID7LdWzQYzEYRH2L0zHXkR6-bs6n2YGxFI34LsBU9CBKdlp_GILmCQiUlkVRfZQ-A_EjiIGDQsXO_6QqEm_medSAHW6qNNESoRlQu3HyvgiZscu9pfiWAuoM-hM65ystsKYoXcDC37h-2onoLUal081goX5fVs5aejWHC5wnHu58h5_UeXH9yZQ6qTQY4t249ZR2nlO9afCkd2cMwuY4wmRsimmW6fgbQaKK2Bq9kfhWlg6gmWaDSW-Aox2aDP2YU4TmoUPvuZJAIgCZjj6YVVYJfItP3l11t4ueO95fw86RgQ_ULqBPhEFY50bmK8-jv2xRVI_yjY_OxZsQcHSoGwZwEZsiFNTfNgAAT2cFbWQiHrHHFAbg3lipeVLGz47qmV4xM-QhvhvHwv7X3L-3AoboKMw6nz103WuaRSywS-vlN2K2rh51ghuMpwmpBEIMs-sDmnpqDVZNWrC6pd_UNsnVD0szjiwtHGvpDk7pc_Coa2p9dSpupW5o221nEG3yuBORoZQYVWEYvg1OMEmsEDTeQ4STQDVYSYdKexFIcsE6O6_XSJ3qljJ0QCGEsKzjyY04Wy9KNoYw9ia_88rg6yPVV-XKLqC2zs5r2CO-nmJpp2pVv4wrdfyu50sCvArt3yLurgOQe-svzcafXr0mHzKeYbulnpu1EGBdNh3WeLsAMHc-kwkIMn6-AGskD2c2sjvxQEOqPqRNbmOTi_ouPcFC_QuLxFf2-E06UGjjcpEu9fTOl_44KKi7op2WcbdAN6M35QN6u2Y)) on the topic we see that:
#
# $$< \dot{m}_{vir} > = 42 (\frac{m_{vir}}{10^{12}M_{\odot}})^{1.127} (1 + 1.17z) \sqrt{\Omega_{m}(1+z)^3 + \Omega_{\Lambda}}$$
#
# If we want to check we'd better be in the correct range of masses where $\epsilon = 1$ (see below), and obtain:
#
# $$\frac{m_{vir}(1 + z)^{3/2}}{m_{*}(1+\eta)} \propto \frac{(1+z)^{3/2}}{(1+\eta)m_{vir}}$$
#
# In order to have a constant we can only check whether:
#
# - $\eta >> 1$
# - $\eta \propto \frac{1}{m_{vir}}$
#
# ### Option B
#
# The reservoir is not at equilibrium. [...]
#
#
# ### A note on the $\epsilon$ value in $\texttt{SFR} = \epsilon m_{gas}$:
#
# Considering the incoming baryonic matter: it needs to cool down to fall in. Why? Because otherwise the pressure due to the heating keeps on expanding the gas and there is no efficient accretion in the central bulge.
# There are mass ranges in which it cools efficiently:
#
# $$\epsilon = \begin{cases} 0 \ \ \text{if} \ \ m_{vir} > 10^{12} M_{\odot} \\ 0 \ \ \text{if} \ \ m_{vir} < 10^{9} M_{\odot} \\ 1 \ \ \text{elsewhere} \end{cases}$$
#
# There are then ranges for which the incoming mass is not enough to accrete around the bulge, so perhaps we need another process to probe. AGN?

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy import units as u
from astropy.io import fits
from astropy.cosmology import Planck18
from astropy.modeling import models
import corner
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV
import scipy
from scipy.optimize import curve_fit
#graphic stuff
from matplotlib.colors import LinearSegmentedColormap
import mpl_scatter_density
# Make the norm object to define the image stretch
from astropy.visualization import LogStretch
from astropy.visualization.mpl_normalize import ImageNormalize
norm = ImageNormalize(vmin=0., vmax=1000, stretch=LogStretch())

# %config InlineBackend.figure_format='retina'

# %%
# mask each bin of redshift for the analysis:

def bin_redshift(matrix,step):
    i=np.min(matrix[:,0])
    masks=[]
    while(i<np.max(matrix[:,0])-step):
        masks.append(((matrix[:,0]>i) & (matrix[:,0]<i+step)))
        i=i+step
    return(masks)

# find optimal descriptive kde:

def kde_sklearn(data, bandwidth = 1.0):
    xgrid=np.linspace(np.min(data),np.max(data),1000)
    kde_skl = KernelDensity(bandwidth = bandwidth)
    kde_skl.fit(data[:, np.newaxis])
    log_pdf = kde_skl.score_samples(xgrid[:, np.newaxis]) # sklearn returns log(density)
    return np.exp(log_pdf)

# select best binning via CV and evaluate kde:

def KDE_binning(x):
    bwrange = np.linspace(0.01,1.0, 30) # Test 30 bandwidths from 0.1 to 1.0
    K = 5 # Do 5-fold cross validation
    grid = GridSearchCV(KernelDensity(), {'bandwidth': bwrange}, cv= K) # Try each bandwidth with K-folds
    grid.fit(x[:,None]) #Fit the histogram data that we started the lecture with.
    h_opt = grid.best_params_['bandwidth']
    pdf=kde_sklearn(x,h_opt)
    return pdf

def KDE_binning_LONGDATASET(x):
    bwrange = np.linspace(0.1, 1.0, 5) # Test 30 bandwidths from 0.1 to 1.0
    K = 2 # Do 5-fold cross validation
    grid = GridSearchCV(KernelDensity(), {'bandwidth': bwrange}, cv= K) # Try each bandwidth with K-folds
    grid.fit(x[:,None]) #Fit the histogram data that we started the lecture with.
    h_opt = grid.best_params_['bandwidth']
    pdf=kde_sklearn(x,h_opt)
    return pdf

# %% [markdown]
# # 3dHST dataset

# %% [markdown]
# ### Data fetch and mask-making

# %%
#import data
data_= fits.open('3dhst_catalogue.fits');
rs = data_[1].data['Redshift']
mass = data_[1].data['Log_stellar_mass_Msun']
SFR = data_[1].data['Log_SFR_Msun_yr']
matrix_pre = np.column_stack((rs,mass,SFR))
cond_pre = (matrix_pre[:,2]>-20)
matrix = matrix_pre[cond_pre]

# %%
min_mass=10
cond = (matrix[:,1]>min_mass) & (matrix[:,0]<2)
good_matrix=matrix[cond]
print("pre-cleaning matrix shape:", matrix.shape)
print("post-cleaning matrix shape:", good_matrix.shape)
# Out:
# pre-cleaning matrix shape: (1446, 3)
# post-cleaning matrix shape: (668, 3)

# %% [markdown]
# Visualization of distribution of masses with respect to the redshift:

# %%
fig = plt.figure(figsize=(7, 5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(matrix[:, 0], matrix[:, 1], c='lightskyblue', s = 5.5, label='data')
ax.scatter(good_matrix[:, 0], good_matrix[:, 1], c='blue', s = 5.5, label='selected data')
ax.set_ylabel("$\log{(M_{*}/M_{\odot})}$")
ax.set_xlabel("$z$")
ax.set_title("$M_{*}(z)$ ")

plt.axhline(y=10, c='red', label="mass threshold ($M_{*} > 10^{10} M_{{\odot}}$)", linestyle='-.')
plt.axvline(x=2, c='green', label='redshift threshold (z < 2)', linestyle='-.')
plt.legend(loc='lower right', fontsize=12)
plt.savefig('M_redshift.pdf', dpi=200)

# %% [markdown]
# Visualization of sSFR with respect to the redshift

# %% [markdown]
# To be sure we are not taking outliers from what we called the "main sequence" we cut the data further to keep things clean:

# %%
cond_sSFR = (good_matrix[:,2]-good_matrix[:,1]) > -14
final_matrix = np.column_stack((good_matrix[:,0][cond_sSFR], (good_matrix[:,2] - good_matrix[:,1])[cond_sSFR]))

# %%
fig = plt.figure(figsize=(7, 5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(matrix[:, 1], matrix[:, 2]-matrix[:,1], c='lightskyblue', s = 5.5, label='data')
ax.scatter(good_matrix[:,1][cond_sSFR], final_matrix[:, 1], c='blue', s = 5.5, label='selected data')

ax.set_xlabel("$\log{(M_{*}/M_{\odot})}$")
ax.set_ylabel("$\log{(sSFR / yr^{-1})}$")
ax.set_title("$sSFR(M_{*})$")
plt.axvline(x=min_mass, c='red', label='mass threshold ( $M_{*} > 10^{10} M_{{\odot}}$ )', linestyle='-.')
plt.axhline(y=-14, c='orange', label=f'sSFR threshold (log(sSFR) > -14)', linestyle='-.')
plt.legend(loc='lower left', fontsize=12)
plt.savefig('sSFR_M.pdf', dpi=200)

# %%
print("post-cleaning matrix shape:", final_matrix.shape)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')

ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False

ax.scatter(matrix[:,0], matrix[:,1], matrix[:,2]-matrix[:,1], color='lightskyblue',alpha=0.5, label='data')
ax.scatter(good_matrix[:,0][cond_sSFR], good_matrix[:,1][cond_sSFR], final_matrix[:,1], color='blue',alpha=1, label='selected data')
ax.set_xlabel('z')
ax.set_ylabel("$\log{(M_{*}/M_{\odot})}$")
ax.set_zlabel("$\log{(sSFR / yr^{-1})}$")
ax.set_title("$sSFR(z,M_{*})$")
plt.legend(loc='upper left', fontsize=15)
ax.view_init(20, 140)
plt.savefig('z_M_sSFR.pdf',dpi=200)
plt.show()
# Out:
# post-cleaning matrix shape: (653, 2)

# %% [markdown]
# ### KDE of quantities:
#
# - $M_{*}$
# - SFR

# %%
#creating masks: here we decide the dimensions of the bins for the redshift
masks=bin_redshift(good_matrix, 0.25)

# %%
pdfs=[]
plt.figure(figsize=(8, 5))
xgrid=np.linspace(10,11.5,1000)

for mask in masks:
    x = good_matrix[:,1][mask]
    pdfs.append(KDE_binning(x[:]))
    
indeces = np.linspace(1, len(pdfs), len(pdfs))

for pdf, i in zip(pdfs, indeces):
    plt.plot(xgrid, pdf, label='mask '+str(i))
plt.title("Evolution of the $M_*$ KDE over $z$")    
plt.legend(loc = 'upper right', fontsize = 18)
plt.xlabel(r"$\log{M_*} [\log{M_{\odot}}]$")
plt.ylabel(r"KDE")
plt.show();

# %%
#creating masks: here we decide the dimensions of the bins for the redshift
masks=bin_redshift(final_matrix, 0.25)

# %%
pdfs = []
plt.figure(figsize=(8, 5))
xgrid = np.linspace(min(final_matrix[:, 1]), max(final_matrix[:, 1]), 1000)

for mask in masks:
    x = final_matrix[:, 1][mask]
    pdfs.append(KDE_binning(x[:]))
    
indeces = np.linspace(1, len(pdfs), len(pdfs))

for pdf,i in zip(pdfs,indeces):
    plt.plot(xgrid, pdf, label='mask '+str(i))
    
plt.legend(loc='upper left', fontsize=18)
plt.xlabel(r"$\log{sSFR} \ [\log{1/yr}]$")
plt.ylabel(r"KDE")
plt.title("Evolution of the sSFR KDE over $z$", fontsize=15)
plt.show();

# %% [markdown]
# # ----------- NEW PART -------------

# %% [markdown]
# ## Bootstrap on 3DHST

# %%
from astroML.resample import bootstrap
from astroML.stats import sigmaG

N = int(1e5)

sSFR = []
z = []
sigmas = []
newsigmas = []

for mask in masks:

    x = final_matrix[mask]

    z.append(np.median((x[:, 0])))
    sSFR.append(np.median(x[:, 1]))
    sigmas.append(sigmaG(x[:, 1]))
    data1 = bootstrap(x[:, 1], N, sigmaG, kwargs=dict(axis=1))
    newsigmas.append(sigmaG(np.concatenate((x[:, 1], np.array(data1)), axis=0)))
    #newsigmas.append(sigmaG(np.array(data1)))


z = np.array(z)
sSFR = np.array(sSFR)
sigmas = np.array(sigmas)
newsigmas = np.array(newsigmas)

print('Before Bootstrap sigmas are: {}. Shape is: {}.'.format(sigmas, sigmas.shape))
print('After Bootstrap sigmas are: {}. Shape is: {}.'.format(newsigmas, newsigmas.shape))
# Out:
# Before Bootstrap sigmas are: [1.40105907 1.09712592 1.21202777 1.31951543 1.46036374]. Shape is: (5,).
# After Bootstrap sigmas are: [0.1360082  0.13188664 0.14150297 0.09341943 0.10441019]. Shape is: (5,).

# %% [markdown]
# ## SDSS redshift bin

# %%
#import data
data_1= fits.open('sdss_mpajhu_catalogue.fits');

rs_1 = data_1[1].data['Redshift']
mass_1 = data_1[1].data['Log_stellar_mass_Msun']
SFR_1 = data_1[1].data['Log_SFR_Msun_yr']
matrix_1 = np.column_stack((rs_1,mass_1,SFR_1))

# %%
#Masking same as 3dhst
data_cond_2 = (matrix_1[:, 0] < 2.) & (matrix_1[:, 1] > 10) & (matrix_1[:, 2] >-20 )

print("pre-cleaning matrix shape:", matrix_1.shape)

cleaned_matrix_1 = matrix_1[data_cond_2]

print("post-cleaning matrix shape:", cleaned_matrix_1.shape)
# Out:
# pre-cleaning matrix shape: (1472581, 3)
# post-cleaning matrix shape: (671303, 3)

# %% [markdown]
# ## Computing sSFR for SDSS

# %%
final_sdss_matrix = np.column_stack([cleaned_matrix_1[:, 0], cleaned_matrix_1[:, 2] - cleaned_matrix_1[:, 1]])

# %%
#creating masks: here we decide the dimensions of the bins for the redshift
sdss_masks = bin_redshift(final_sdss_matrix, 0.25)

# %%
err = []
for mask in masks:
    
    x = final_matrix[mask]
    err.append(np.std(x[:, 1]))

# %% [markdown]
# ## Computing final SDSS matrix with redshift and sSFR

# %%
#Binning SDSS datasets
sdss_z = []
sdss_sSFR = []
sdss_err_sSFR = []

for mask in sdss_masks:

    x = final_sdss_matrix[mask]

    sdss_z.append(np.median((x[:, 0])))
    sdss_sSFR.append(np.median(x[:, 1]))
    #sdss_err_sSFR.append(sigmaG(x[:, 1]))
    sdss_err_sSFR.append(np.std(x[:, 1]))

sdss_z = np.array(sdss_z)
sdss_sSFR = np.array(sdss_sSFR)
sdss_err_sSFR = np.array(sdss_err_sSFR)

# %%
#Plotting

plt.figure(figsize=(8, 5))

plt.scatter(z, sSFR, label='3D-HST', c='blue')
plt.errorbar(z, sSFR, err, fmt='.', ecolor='k', alpha=0.5)

plt.scatter(sdss_z, sdss_sSFR, label='SDSS', c='red')
plt.errorbar(sdss_z, sdss_sSFR, sdss_err_sSFR, ecolor='k', alpha=0.5)

#plt.scatter(z[1:4], sSFR[1:4], label='Viable 3DHST', c='blue')
#plt.errorbar(z[1:4], sSFR[1:4], err[1:4], ecolor='k', alpha=0.5)
plt.xlabel(r"$z$", fontsize=15)
plt.ylabel(r"$\log{(sSFR / yr^{-1})}$")
plt.title('$sSFR (z) $', fontsize=15)
plt.legend(loc='upper left')
plt.savefig('ssfr_1_plot.pdf')
plt.show()

# %% [markdown]
# ### Data fetch ad mask-making

# %%
#Fitting WIP

from astroML.linear_model import PolynomialRegression

#Linear Fit in loglog
model = PolynomialRegression(1)

x = np.log10(1 + np.array(z))
sdss_x = np.log10(1 + sdss_z)

xfit = np.concatenate((sdss_x, x), axis=0)
yfit = np.concatenate((sdss_sSFR, sSFR), axis=0)
errfit = np.concatenate((sdss_err_sSFR, err), axis=0)

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt    
from scipy import stats

# pip install uncertainties, if needed
try:
    import uncertainties.unumpy as unp
    import uncertainties as unc

except:
    try:
        from pip import main as pipmain
    except:
        from pip._internal import main as pipmain
    pipmain(['install','uncertainties'])
    import uncertainties.unumpy as unp
    import uncertainties as unc

n=len(yfit)

def f(x, a, b):
    return a * x + b

popt, pcov = curve_fit(f, xfit, yfit, sigma=errfit)

# retrieve parameter values
a = popt[0]
b = popt[1]
print('Optimal Values')
print('a: ' + str(a))
print('b: ' + str(b))

# compute r^2
r2 = 1.0-(sum((yfit-f(xfit,a,b))**2)/((n-1.0)*np.var(yfit,ddof=1)))
print('R^2: ' + str(r2))
print(pcov)
# calculate parameter confidence interval
a,b = unc.correlated_values(popt, pcov)
print('Uncertainty')
print('a: ' + str(a))
print('b: ' + str(b))

# plot data
plt.scatter(xfit, yfit, s=3, label='Data')
plt.errorbar(xfit, yfit, errfit, fmt='.')

# calculate regression confidence interval
px = np.linspace(0.04,0.5,100)
py = a*px+b
nom = unp.nominal_values(py)
std = unp.std_devs(py)

def predband(x, xd, yd, p, func, conf=0.95):
    # x = requested points
    # xd = x data
    # yd = y data
    # p = parameters
    # func = function name
    alpha = 1.0 - conf    # significance
    N = xd.size          # data sample size
    var_n = len(p)  # number of parameters
    # Quantile of Student's t distribution for p=(1-alpha/2)
    q = stats.t.ppf(1.0 - alpha / 2.0, N - var_n)
    # Stdev of an individual measurement
    se = np.sqrt(1. / (N - var_n) * \
                 np.sum((yd - func(xd, *p)) ** 2))
    # Auxiliary definitions
    sx = (x - xd.mean()) ** 2
    sxd = np.sum((xd - xd.mean()) ** 2)
    # Predicted values (best-fit model)
    yp = func(x, *p)
    # Prediction band
    dy = q * se * np.sqrt(1.0+ (1.0/N) + (sx/sxd))
    # Upper & lower prediction bands.
    lpb, upb = yp - dy, yp + dy
    return lpb, upb

lpb, upb = predband(px, xfit, yfit, popt, f, conf=0.95)

# plot the regression
plt.plot(px, nom, c='black', label='Linear Fit')

# uncertainty lines (95% confidence)
#plt.plot(px, nom - 1.96 * std, c='orange',\
#         label='95% Confidence Region')
#plt.plot(px, nom + 1.96 * std, c='orange')

# prediction band (95% confidence)
plt.plot(px, lpb, 'k--',label='Prediction Band')
plt.plot(px, upb, 'k--')
plt.ylabel('$\log(sSFR/yr^{-1})$')
plt.xlabel('log(1+z)')
plt.legend(loc='best')

# save and show figure
plt.savefig('regression.pdf')
plt.show()
# Out:
# Optimal Values
# a: 3.599493135819165
# b: -11.52020734539756
# R^2: 0.8720091990835679
# [[ 0.40490697 -0.10818607]
#  [-0.10818607  0.03535408]]
# Uncertainty
# a: 3.6+/-0.6
# b: -11.52+/-0.19

# %% [markdown]
# # ----------- END OF NEW PART -------------

# %% [markdown]
# # SDSS dataset:

# %%
matrix_1=matrix_1[((matrix_1[:,1]>7) & ((matrix_1[:,2]>-20)))]
# It contains the data for all masses just to visualize them,
# contrary to cleaned_matrix_1 used for the fit

# %% [markdown]
# Visualize the distribution of masses with respect to the redshift:

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
density = ax.scatter_density(matrix_1[:, 0], matrix_1[:, 1], norm=norm, cmap='jet')
fig.colorbar(density, label='Number of points per pixel')
ax.set_ylabel("$\log{M_{*}} \ [\log{M_{\odot}}]$")
ax.set_xlabel("$z$")
ax.set_title("$M_{*}(z)$ ");
# Out:
# /home/alice/.local/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:77: RuntimeWarning: All-NaN slice encountered
#   vmin = self._density_vmin(array)
# /home/alice/.local/lib/python3.10/site-packages/mpl_scatter_density/generic_density_artist.py:82: RuntimeWarning: All-NaN slice encountered
#   vmax = self._density_vmax(array)

# %% [markdown]
# Visualize the distribution of sSFRs with respect to the redshift:

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
density = ax.scatter_density(matrix_1[:, 0], matrix_1[:, 2] - matrix_1[:, 1], norm=norm, cmap='jet')
fig.colorbar(density, label='Number of points per pixel')
ax.set_xlabel("$z$")
ax.set_ylabel("$\log{sSFR} \ [\log{1/yr}]$")
ax.set_title("$sSFR(z)$ ", fontsize=15)
plt.axhline(y=-10, c='r', linestyle='--')
plt.axvline(x=0.075, c='r', linestyle='--', label='MS')
plt.axhline(y=-12, c='g', linestyle='--', label='Secondary')
plt.axhline(y=-11, linestyle='--', c='black')
plt.axvline(x=0.1, c='g', linestyle='--')
plt.legend(fontsize='xx-large');

# %% [markdown]
# Visualize the distribution of masses with respect to the SFR (all in log-scale):

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
density = ax.scatter_density(matrix_1[:, 1], matrix_1[:, 2], norm=norm, cmap='jet')
fig.colorbar(density, label='Number of points per pixel')
ax.set_xlabel("$\log{M_{*}} \ [\log{M_{\odot}}]$")
ax.set_ylabel("$\log{SFR} \ [\log{M_{\odot}/yr}]$")
ax.set_title("$SFR(M_{*})$ ");

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1, 1, 1, projection='scatter_density')
density = ax.scatter_density(matrix_1[:, 1], matrix_1[:, 2] - matrix_1[:, 1], norm=norm, cmap='jet')
fig.colorbar(density, label='Number of points per pixel')
ax.set_xlabel("$\log{M_{*}} \ [\log{M_{\odot}}]$")
ax.set_ylabel("$\log{sSFR} \ [\log{1/yr}]$")
plt.axhline(y=-10, c='r', linestyle='--')
plt.axvline(x=10, c='r', linestyle='--', label='MS')
plt.axhline(y=-12, c='g', linestyle='--', label='Secondary')
plt.axvline(x=11, c='g', linestyle='--')
ax.set_title("$sSFR(M_{*})$ ")
plt.legend(fontsize='xx-large');

# %% [markdown]
# Here we have a more complete dataset, and the graph seems to hint to the fact that there are two populations of galaxies' SFR that depend on the mass. First we see the kernel density, the same way as before, then we model the problem of the SFR as a function of the masses.

# %% [markdown]
# ### Histograms of quantities:
#
# - $M_{*}$
# - SFR

# %%
#creating masks: here we decide the dimensions of the bins for the redshift
masks=bin_redshift(matrix_1,0.05)

# %%
fig = plt.figure(figsize=(8, 5))
for mask, i in zip(masks, range(0, len(masks))):

    plt.hist(matrix_1[:, 1][mask], density=True, alpha=0.5, label=f'mask {i}', bins=30)
    
plt.legend(loc='upper left', fontsize=15)
plt.xlabel('$M_{*}$', fontsize=20);

# %%
fig = plt.figure(figsize=(8, 5))
for mask, i in zip(masks, range(0, len(masks))):

    plt.hist(matrix_1[:, 2][mask] - matrix_1[:, 1][mask], density=True, alpha=0.5, label=f'mask {i}', bins=30)
    
plt.legend(loc='upper left', fontsize=15)
plt.xlabel('$sSFR$', fontsize=20);

# %%
fig = plt.figure(figsize=(15, 10))
masks=bin_redshift(matrix_1,0.05)
for mask, i in zip(masks, range(0, len(masks))):
    ax = fig.add_subplot(231+i)
    ax.hist(matrix_1[:, 2][mask] - matrix_1[:, 1][mask], density=True, alpha=0.5, label=f'mask {i}', bins=30, color='C%i'%i)
    ax.axvline(np.median((matrix_1[:, 2][mask] - matrix_1[:, 1][mask])[(matrix_1[:, 2][mask] - matrix_1[:, 1][mask])>-11]), 0,1, label='median')
    #plt.xlim(-11,-8)
    plt.legend(loc='upper right', fontsize=15)
    plt.xlabel('$sSFR$', fontsize=20);

# %%
mask_pop = ((matrix_1[:, 2]  - matrix_1[:, 1]) > -11)

matrix_1_pop = np.column_stack((matrix_1[:, 0][mask_pop], (matrix_1[:, 2] - matrix_1[:, 1])[mask_pop]))

masks=bin_redshift(matrix_1_pop, 0.05)
zs_means = np.linspace(np.min(matrix_1_pop[:, 0]), np.max(matrix_1_pop[:, 0]), len(masks))

means = []

for mask in masks:

    means.append(np.median(matrix_1_pop[:, 1][mask]))
    
fig = plt.figure(figsize=(15, 10))

for mask, i in zip(masks, range(0, len(masks))):
    ax = fig.add_subplot(231+i)
    counts, b, _ = ax.hist(matrix_1_pop[:, 1][mask], density=True, alpha=0.5, label=f'mask {i}', bins=30)
    m = np.argmax(counts)
    #plt.xlim(-11,-8)
    ax.axvline(means[i], 0,1, label='median', c='C1')
    ax.axvline(b[m] + (b[m+1]-b[m])/2, 0,1, label='max of the histogram', c='C2')
    plt.legend(loc='upper right', fontsize=10)
    plt.xlabel('$sSFR$', fontsize=15);

# %% [markdown]
# I noticed something, but it might be biased due to the choice of bins: the bimodal distribution appears only at very small redshifts (mask_index > 0), so perhaps we're not that wrong using the other dataset as well!

# %% [markdown]
# ### SFR vs redshift

# %%
SFR=[]
z=[]
err=[]

plt.figure(figsize=(8, 5))
masks = bin_redshift(matrix_1, 0.005)
#print(masks)

for mask in masks:
    vector=matrix_1[mask]
    SFR.append(np.median(vector[:,2]))
    err.append(np.std(vector[:,2]))
    z.append(np.median(vector[:,0]))
    
#z=np.array(z)+1
plt.scatter(z,SFR)
plt.xlabel(r"$z$", fontsize=15)
plt.ylabel(r"$\log{SFR} [\log{1/yr}]$")
#plt.xlim(0,0.3)
plt.title('SFR at different $z$', fontsize=15);
plt.show()

sSFR=[]
z=[]
err=[]

plt.figure(figsize=(8, 5))
for mask in masks:
    vector=matrix_1[mask]
    sSFR.append(np.median(vector[:,2] - vector[:,1]))
    err.append(np.std(vector[:,2] - vector[:,1]))
    z.append(np.median(vector[:,0]))
    
#z=np.array(z)+1
plt.scatter(z,sSFR)
plt.xlabel(r"$z$", fontsize=15)
plt.ylabel(r"$\log{sSFR} [\log{1/yr}]$")
#plt.xlim(0,0.3)
plt.title('sSFR at different $z$', fontsize=15);
